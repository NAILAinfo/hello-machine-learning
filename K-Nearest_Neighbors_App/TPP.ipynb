# %%
import pandas as pd

data = {
    'packet_size': [200, 450, 300, 700, 1000, 150, 400, 800, 130, 600],
    'connection_time': [30, 50, 25, 80, 10, 100, 15, 45, 90, 12],
    'malicious': [0, 0, 0, 1, 0, 1, 0, 0, 1, 0]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    packet_size  connection_time  malicious
# 0          200               30          0
# 1          450               50          0
# 2          300               25          0
# 3          700               80          1
# 4         1000               10          0
# 5          150              100          1
# 6          400               15          0
# 7          800               45          0
# 8          130               90          1
# 9          600               12          0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error, accuracy_score, classification_report



x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = StandardScaler()  
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)
x = df[['pscket_size', 'connection_time']]
y = df['malicious']
for k in [1, 3, 5]:
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train_scaled, y_train)
    y_pred = model.predict(x_test_scaled)
    
    accuracy = accuracy_score(y_test, y_pred)
    print(f"\nAccuracy for k={k}: {accuracy:.2f}")
    print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       4 from sklearn.neighbors import KNeighborsClassifier
#       5 from sklearn.metrics import mean_absolute_error, accuracy_score, classification_report
# ----> 9 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
#      11 scaler = StandardScaler()
#      12 x_train_scaled = scaler.fit_transform(x_train)
#
# NameError: name 'x' is not defined
